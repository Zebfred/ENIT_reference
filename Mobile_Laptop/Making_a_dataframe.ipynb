# %%
import pandas as pd

# %%
df_fea = pd.read_csv('W_features.csv')
df_sam_sub = pd.read_csv('W_sample_submission.csv')
df_store = pd.read_csv('W_store.csv')

# %%
print(df_fea.shape)
df_fea.head()
# Out:
# (8190, 14)
#    Unnamed: 0  index  Store        Date  Temperature  Fuel_Price  MarkDown1  \
# 0           0      0      1  2010-02-05        42.31       2.572        NaN
# 1           1      1      1  2010-02-12        38.51       2.548        NaN
# 2           2      2      1  2010-02-19        39.93       2.514        NaN
# 3           3      3      1  2010-02-26        46.63       2.561        NaN
# 4           4      4      1  2010-03-05        46.50       2.625        NaN
#
#    MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0        NaN        NaN        NaN        NaN  211.096358         8.106
# 1        NaN        NaN        NaN        NaN  211.242170         8.106
# 2        NaN        NaN        NaN        NaN  211.289143         8.106
# 3        NaN        NaN        NaN        NaN  211.319643         8.106
# 4        NaN        NaN        NaN        NaN  211.350143         8.106
#
#    IsHoliday
# 0          0
# 1          1
# 2          0
# ...

# %%
print(df_sam_sub.shape)
df_sam_sub.head()
# Out:
# (115064, 4)
#    Unnamed: 0  index              Id  Weekly_Sales
# 0           0      0  1_1_2012-11-02             0
# 1           1      1  1_1_2012-11-09             0
# 2           2      2  1_1_2012-11-16             0
# 3           3      3  1_1_2012-11-23             0
# 4           4      4  1_1_2012-11-30             0

# %%
print(df_store.shape)
df_store.head()
# Out:
# (45, 5)
#    Unnamed: 0  index  Store Type    Size
# 0           0      0      1    A  151315
# 1           1      1      2    A  202307
# 2           2      2      3    B   37392
# 3           3      3      4    A  205863
# 4           4      4      5    B   34875

# %%
df_store_sam = pd.merge( df_store, df_sam_sub, how = 'outer', on='index')

# %%
print(df_store_sam.shape)
df_store_sam.head()
# Out:
# (115064, 8)
#    Unnamed: 0_x  index  Store Type      Size  Unnamed: 0_y              Id  \
# 0           0.0      0    1.0    A  151315.0             0  1_1_2012-11-02
# 1           1.0      1    2.0    A  202307.0             1  1_1_2012-11-09
# 2           2.0      2    3.0    B   37392.0             2  1_1_2012-11-16
# 3           3.0      3    4.0    A  205863.0             3  1_1_2012-11-23
# 4           4.0      4    5.0    B   34875.0             4  1_1_2012-11-30
#
#    Weekly_Sales
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df_store_sam.isnull().sum()
# Out:
# Unnamed: 0_x    115019
# index                0
# Store           115019
# Type            115019
# Size            115019
# Unnamed: 0_y         0
# Id                   0
# Weekly_Sales         0
# dtype: int64

# %%
mergedDF = df_store.merge(df_sam_sub, on='index', suffixes='Type')
# Out:
# C:\Users\Zebfred\miniconda3\lib\site-packages\pandas\core\frame.py:8192: FutureWarning: Passing 'suffixes' as a <class 'str'>, is not supported and may give unexpected results. Provide 'suffixes' as a tuple instead. In the future a 'TypeError' will be raised.
#   return merge(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-da2442925fd1> in <module>
# ----> 1 mergedDF = df_store.merge(df_sam_sub, on='index', suffixes='Type')
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8190         from pandas.core.reshape.merge import merge
#    8191
# -> 8192         return merge(
#    8193             self,
#    8194             right,
#
# ...

# %%
mergedDF = df_store.merge(df_sam_sub, on='index')

# %%
mergedDF.shape
# Out:
# (45, 8)

# %%
mergedDF.isnull().sum()
# Out:
# Unnamed: 0_x    0
# index           0
# Store           0
# Type            0
# Size            0
# Unnamed: 0_y    0
# Id              0
# Weekly_Sales    0
# dtype: int64

# %%
mergedDF = df_sam_sub.merge(df_store, on='index')

# %%
mergedDF.shape
# Out:
# (45, 8)

# %%
mergedDF.isnull().sum()
# Out:
# Unnamed: 0_x    0
# index           0
# Id              0
# Weekly_Sales    0
# Unnamed: 0_y    0
# Store           0
# Type            0
# Size            0
# dtype: int64

# %%
df_sam_sub.shape
# Out:
# (115064, 4)

# %%
left_join = pd.merge(df_sam_sub, df_store, on = 'index', how= 'left')
left_join.shape
# Out:
# (115064, 8)

# %%
left_join.isnull().sum()
# Out:
# Unnamed: 0_x         0
# index                0
# Id                   0
# Weekly_Sales         0
# Unnamed: 0_y    115019
# Store           115019
# Type            115019
# Size            115019
# dtype: int64

# %%
left_join = pd.concat([df_sam_sub, df_store], axis=1)
left_join.shape
left_join.isnull().sum()
# Out:
# Unnamed: 0           0
# index                0
# Id                   0
# Weekly_Sales         0
# Unnamed: 0      115019
# index           115019
# Store           115019
# Type            115019
# Size            115019
# dtype: int64

# %%
left_join.shape
# Out:
# (115064, 9)

# %%
left_join
# Out:
#         Unnamed: 0   index                Id  Weekly_Sales  Unnamed: 0  index  \
# 0                0       0    1_1_2012-11-02             0         0.0    0.0
# 1                1       1    1_1_2012-11-09             0         1.0    1.0
# 2                2       2    1_1_2012-11-16             0         2.0    2.0
# 3                3       3    1_1_2012-11-23             0         3.0    3.0
# 4                4       4    1_1_2012-11-30             0         4.0    4.0
# ...            ...     ...               ...           ...         ...    ...
# 115059      115059  115059  45_98_2013-06-28             0         NaN    NaN
# 115060      115060  115060  45_98_2013-07-05             0         NaN    NaN
# 115061      115061  115061  45_98_2013-07-12             0         NaN    NaN
# 115062      115062  115062  45_98_2013-07-19             0         NaN    NaN
# 115063      115063  115063  45_98_2013-07-26             0         NaN    NaN
#
#         Store Type      Size
# ...

# %%
df_sam_sub
# Out:
#         Unnamed: 0   index                Id  Weekly_Sales
# 0                0       0    1_1_2012-11-02             0
# 1                1       1    1_1_2012-11-09             0
# 2                2       2    1_1_2012-11-16             0
# 3                3       3    1_1_2012-11-23             0
# 4                4       4    1_1_2012-11-30             0
# ...            ...     ...               ...           ...
# 115059      115059  115059  45_98_2013-06-28             0
# 115060      115060  115060  45_98_2013-07-05             0
# 115061      115061  115061  45_98_2013-07-12             0
# 115062      115062  115062  45_98_2013-07-19             0
# 115063      115063  115063  45_98_2013-07-26             0
#
# [115064 rows x 4 columns]

# %%
df_store.shape
# Out:
# (45, 5)

# %%
df_fea.shape
# Out:
# (8190, 14)

# %%
df_store
# Out:
#     Unnamed: 0  index  Store Type    Size
# 0            0      0      1    A  151315
# 1            1      1      2    A  202307
# 2            2      2      3    B   37392
# 3            3      3      4    A  205863
# 4            4      4      5    B   34875
# 5            5      5      6    A  202505
# 6            6      6      7    B   70713
# 7            7      7      8    A  155078
# 8            8      8      9    B  125833
# 9            9      9     10    B  126512
# 10          10     10     11    A  207499
# 11          11     11     12    B  112238
# 12          12     12     13    A  219622
# 13          13     13     14    A  200898
# 14          14     14     15    B  123737
# 15          15     15     16    B   57197
# 16          16     16     17    B   93188
# 17          17     17     18    B  120653
# 18          18     18     19    A  203819
# 19          19     19     20    A  203742
# 20          20     20     21    B  140167
# ...

# %%
left_join = pd.merge(df_fea, df_store, on = 'Store', how= 'left')
left_join.shape
# Out:
# (8190, 18)

# %%
left_join
# Out:
#       Unnamed: 0_x  index_x  Store        Date  Temperature  Fuel_Price  \
# 0                0        0      1  2010-02-05        42.31       2.572
# 1                1        1      1  2010-02-12        38.51       2.548
# 2                2        2      1  2010-02-19        39.93       2.514
# 3                3        3      1  2010-02-26        46.63       2.561
# 4                4        4      1  2010-03-05        46.50       2.625
# ...            ...      ...    ...         ...          ...         ...
# 8185          8185     8185     45  2013-06-28        76.05       3.639
# 8186          8186     8186     45  2013-07-05        77.50       3.614
# 8187          8187     8187     45  2013-07-12        79.37       3.614
# 8188          8188     8188     45  2013-07-19        82.84       3.737
# 8189          8189     8189     45  2013-07-26        76.06       3.804
#
#       MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# ...

# %%
left_join.isnull().sum()
# Out:
# Unnamed: 0_x       0
# index_x            0
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# Unnamed: 0_y       0
# index_y            0
# Type               0
# Size               0
# dtype: int64

# %%
print(df_sam_sub.head(1))
left_join.head(1)
# Out:
#    Unnamed: 0  index              Id  Weekly_Sales
# 0           0      0  1_1_2012-11-02             0
#    Unnamed: 0_x  index_x  Store        Date  Temperature  Fuel_Price  \
# 0             0        0      1  2010-02-05        42.31       2.572
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
#
#    Unemployment  IsHoliday  Unnamed: 0_y  index_y Type    Size
# 0         8.106          0             0        0    A  151315

# %%
df_sam_sub.shape
# Out:
# (115064, 4)

# %%
left_join.shape
# Out:
# (8190, 18)

# %%
df_sam_sub
# Out:
#         Unnamed: 0   index                Id  Weekly_Sales
# 0                0       0    1_1_2012-11-02             0
# 1                1       1    1_1_2012-11-09             0
# 2                2       2    1_1_2012-11-16             0
# 3                3       3    1_1_2012-11-23             0
# 4                4       4    1_1_2012-11-30             0
# ...            ...     ...               ...           ...
# 115059      115059  115059  45_98_2013-06-28             0
# 115060      115060  115060  45_98_2013-07-05             0
# 115061      115061  115061  45_98_2013-07-12             0
# 115062      115062  115062  45_98_2013-07-19             0
# 115063      115063  115063  45_98_2013-07-26             0
#
# [115064 rows x 4 columns]

# %%
df_fea
# Out:
#       Unnamed: 0  index  Store        Date  Temperature  Fuel_Price  \
# 0              0      0      1  2010-02-05        42.31       2.572
# 1              1      1      1  2010-02-12        38.51       2.548
# 2              2      2      1  2010-02-19        39.93       2.514
# 3              3      3      1  2010-02-26        46.63       2.561
# 4              4      4      1  2010-03-05        46.50       2.625
# ...          ...    ...    ...         ...          ...         ...
# 8185        8185   8185     45  2013-06-28        76.05       3.639
# 8186        8186   8186     45  2013-07-05        77.50       3.614
# 8187        8187   8187     45  2013-07-12        79.37       3.614
# 8188        8188   8188     45  2013-07-19        82.84       3.737
# 8189        8189   8189     45  2013-07-26        76.06       3.804
#
#       MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0           NaN        NaN        NaN        NaN        NaN  211.096358
# ...

# %%
df_sam_sub.shape
# Out:
# (115064, 4)

# %%
print(df_store.head(1))
print(df_fea.head(1))
print(df_sam_sub.head(1))
# Out:
#    Unnamed: 0  index  Store Type    Size
# 0           0      0      1    A  151315
#    Unnamed: 0  index  Store        Date  Temperature  Fuel_Price  MarkDown1  \
# 0           0      0      1  2010-02-05        42.31       2.572        NaN
#
#    MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0        NaN        NaN        NaN        NaN  211.096358         8.106
#
#    IsHoliday
# 0          0
#    Unnamed: 0  index              Id  Weekly_Sales
# 0           0      0  1_1_2012-11-02             0

# %%
df_fea
# Out:
#       Unnamed: 0  index  Store        Date  Temperature  Fuel_Price  \
# 0              0      0      1  2010-02-05        42.31       2.572
# 1              1      1      1  2010-02-12        38.51       2.548
# 2              2      2      1  2010-02-19        39.93       2.514
# 3              3      3      1  2010-02-26        46.63       2.561
# 4              4      4      1  2010-03-05        46.50       2.625
# ...          ...    ...    ...         ...          ...         ...
# 8185        8185   8185     45  2013-06-28        76.05       3.639
# 8186        8186   8186     45  2013-07-05        77.50       3.614
# 8187        8187   8187     45  2013-07-12        79.37       3.614
# 8188        8188   8188     45  2013-07-19        82.84       3.737
# 8189        8189   8189     45  2013-07-26        76.06       3.804
#
#       MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0           NaN        NaN        NaN        NaN        NaN  211.096358
# ...
