# %%
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
import numpy
from sklearn.model_selection import train_test_split

irisDataset = load_iris()
Data_train, Data_test, Target_train, Target_test = train_test_split(irisDataset["data"], irisDataset["target"],
                                                                    random_state=0)
scores = []
val_k = []

for k in range(1, 100):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(Data_train, Target_train)
    val_k.append(k)
    scores.append(knn.score(Data_test, Target_test)*100)
    print("When k is", k, "the accuracy is", knn.score(Data_test, Target_test)*100)
# Out:
# When k is 1 the accuracy is 97.36842105263158
# When k is 2 the accuracy is 97.36842105263158
# When k is 3 the accuracy is 97.36842105263158
# When k is 4 the accuracy is 97.36842105263158
# When k is 5 the accuracy is 97.36842105263158
# When k is 6 the accuracy is 97.36842105263158
# When k is 7 the accuracy is 97.36842105263158
# When k is 8 the accuracy is 97.36842105263158
# When k is 9 the accuracy is 97.36842105263158
# When k is 10 the accuracy is 97.36842105263158
# When k is 11 the accuracy is 97.36842105263158
# When k is 12 the accuracy is 97.36842105263158
# When k is 13 the accuracy is 97.36842105263158
# When k is 14 the accuracy is 97.36842105263158
# When k is 15 the accuracy is 97.36842105263158
# When k is 16 the accuracy is 97.36842105263158
# When k is 17 the accuracy is 97.36842105263158
# When k is 18 the accuracy is 97.36842105263158
# When k is 19 the accuracy is 97.36842105263158
# When k is 20 the accuracy is 97.36842105263158
# When k is 21 the accuracy is 97.36842105263158
# When k is 22 the accuracy is 97.36842105263158
# When k is 23 the accuracy is 97.36842105263158
# When k is 24 the accuracy is 94.73684210526315
# When k is 25 the accuracy is 94.73684210526315
# When k is 26 the accuracy is 94.73684210526315
# When k is 27 the accuracy is 94.73684210526315
# When k is 28 the accuracy is 92.10526315789474
# When k is 29 the accuracy is 89.47368421052632
# When k is 30 the accuracy is 94.73684210526315
# When k is 31 the accuracy is 94.73684210526315
# When k is 32 the accuracy is 97.36842105263158
# When k is 33 the accuracy is 92.10526315789474
# When k is 34 the accuracy is 94.73684210526315
# When k is 35 the accuracy is 92.10526315789474
# When k is 36 the accuracy is 94.73684210526315
# When k is 37 the accuracy is 92.10526315789474
# When k is 38 the accuracy is 92.10526315789474
# When k is 39 the accuracy is 92.10526315789474
# When k is 40 the accuracy is 86.8421052631579
# When k is 41 the accuracy is 89.47368421052632
# When k is 42 the accuracy is 86.8421052631579
# When k is 43 the accuracy is 86.8421052631579
# When k is 44 the accuracy is 89.47368421052632
# When k is 45 the accuracy is 89.47368421052632
# When k is 46 the accuracy is 89.47368421052632
# When k is 47 the accuracy is 89.47368421052632
# When k is 48 the accuracy is 86.8421052631579
# When k is 49 the accuracy is 89.47368421052632
# When k is 50 the accuracy is 89.47368421052632
# When k is 51 the accuracy is 89.47368421052632
# When k is 52 the accuracy is 86.8421052631579
# When k is 53 the accuracy is 92.10526315789474
# When k is 54 the accuracy is 89.47368421052632
# When k is 55 the accuracy is 89.47368421052632
# When k is 56 the accuracy is 89.47368421052632
# When k is 57 the accuracy is 89.47368421052632
# When k is 58 the accuracy is 89.47368421052632
# When k is 59 the accuracy is 89.47368421052632
# When k is 60 the accuracy is 89.47368421052632
# When k is 61 the accuracy is 89.47368421052632
# When k is 62 the accuracy is 89.47368421052632
# When k is 63 the accuracy is 81.57894736842105
# When k is 64 the accuracy is 81.57894736842105
# When k is 65 the accuracy is 81.57894736842105
# When k is 66 the accuracy is 84.21052631578947
# When k is 67 the accuracy is 84.21052631578947
# When k is 68 the accuracy is 84.21052631578947
# When k is 69 the accuracy is 71.05263157894737
# When k is 70 the accuracy is 68.42105263157895
# When k is 71 the accuracy is 65.78947368421053
# When k is 72 the accuracy is 63.1578947368421
# When k is 73 the accuracy is 63.1578947368421
# When k is 74 the accuracy is 63.1578947368421
# When k is 75 the accuracy is 63.1578947368421
# When k is 76 the accuracy is 63.1578947368421
# When k is 77 the accuracy is 63.1578947368421
# When k is 78 the accuracy is 63.1578947368421
# When k is 79 the accuracy is 63.1578947368421
# When k is 80 the accuracy is 63.1578947368421
# When k is 81 the accuracy is 63.1578947368421
# When k is 82 the accuracy is 63.1578947368421
# When k is 83 the accuracy is 63.1578947368421
# When k is 84 the accuracy is 63.1578947368421
# When k is 85 the accuracy is 60.526315789473685
# When k is 86 the accuracy is 60.526315789473685
# When k is 87 the accuracy is 60.526315789473685
# When k is 88 the accuracy is 60.526315789473685
# When k is 89 the accuracy is 60.526315789473685
# When k is 90 the accuracy is 60.526315789473685
# When k is 91 the accuracy is 60.526315789473685
# When k is 92 the accuracy is 60.526315789473685
# When k is 93 the accuracy is 60.526315789473685
# When k is 94 the accuracy is 60.526315789473685
# When k is 95 the accuracy is 60.526315789473685
# When k is 96 the accuracy is 60.526315789473685
# When k is 97 the accuracy is 60.526315789473685
# When k is 98 the accuracy is 60.526315789473685
# When k is 99 the accuracy is 60.526315789473685

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from scipy.stats import multivariate_normal as mvn
from scipy.stats import multinomial as mlvn
from scipy.stats import bernoulli as brn
# %matplotlib inline

# %%
train_data = np.load('kmnist-train-imgs.npz')['arr_0']
train_labels = np.load('kmnist-train-labels.npz')['arr_0']
test_data = np.load('kmnist-test-imgs.npz')['arr_0']
test_labels = np.load('kmnist-test-labels.npz')['arr_0']

# %%
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
test_labels.shape
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
x_train = train_data.reshape(-1, 784)
y_train = train_labels
x_test = test_data.reshape(-1, 784)
y_test = test_labels

# %%
x_norm = x_train/255
x_test_norm = x_test/255

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
y_test.shape
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
import numpy
from sklearn.model_selection import train_test_split

#irisDataset = load_iris()
#Data_train, Data_test, Target_train, Target_test = train_test_split(irisDataset["data"], irisDataset["target"],
#random_state=0)
scores = []
val_k = []

for k in range(1, 100):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_norm, y_train)
    val_k.append(k)
    scores.append(knn.score(x_test_norm, y_test)*100)
    print("When k is", k, "the accuracy is", knn.score(x_test_norm, y_test)*100)
# Out:
# When k is 1 the accuracy is 92.25
# When k is 2 the accuracy is 90.97
# When k is 3 the accuracy is 91.43
# When k is 4 the accuracy is 91.49000000000001
# When k is 5 the accuracy is 91.33
# When k is 6 the accuracy is 91.06
# When k is 88 the accuracy is 80.52
# When k is 89 the accuracy is 80.45
# When k is 90 the accuracy is 80.31
# When k is 91 the accuracy is 80.22
# When k is 92 the accuracy is 80.13
# When k is 93 the accuracy is 80.06
# When k is 94 the accuracy is 79.95
# When k is 95 the accuracy is 79.91
# When k is 96 the accuracy is 79.83
# When k is 97 the accuracy is 79.82000000000001
# When k is 98 the accuracy is 79.75
# When k is 99 the accuracy is 79.81

# %%
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
import numpy
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plot

irisDataset = load_iris()

#splitting the dataset
Data_train, Data_test, Target_train, Target_test = train_test_split(irisDataset["data"], irisDataset["target"],
                                                                    random_state=0)
x_coords = []
y_coords = []

data_to_predict = numpy.array([[5, 2.9, 1, 0.2]])

#checking accuracy for various values of k
for k in range(1, 100):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(Data_train, Target_train)
    x_coords.append(k)
    y_coords.append(knn.score(Data_test, Target_test)*100)

#training a knn and making a prediction
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(Data_train, Target_train)

predicted_species = knn.predict(data_to_predict)
print("The most probable species the sample will be is " + irisDataset["target_names"][predicted_species][0] + ". " +
      "The machine was tested and got {:.2f}% of its predictions right.".format(knn.score(Data_test, Target_test) * 100))

#plotting the graph
plot.figure()
plot.plot(x_coords, y_coords)
plot.xlabel("Value of k")
plot.ylabel("Accuracy (in %)")
plot.ylim(top = 100)
plot.title("Accuracy for different values of k")
plot.show()

# %%
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
import numpy
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plot
from sklearn.model_selection import cross_val_score
from matplotlib.colors import ListedColormap

irisDataset = load_iris()
sepals = []
sepal_length = irisDataset.data[:, 0]
sepal_width = irisDataset.data[:, 1]
x_coords = []
y_coords = []
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])


def listify(list1, list2):
    for i in range(0, len(list1)):
        temp = [list1[i], list2[i]]
        sepals.append(temp)

listify(sepal_length, sepal_width)
sepals = numpy.array(sepals)

Data_train, Data_test, Target_train, Target_test = train_test_split(sepals,
                                                                    irisDataset["target"], random_state=0)

formatterplot = plot.FuncFormatter(lambda index, *args: irisDataset.target_names[int(index)])

for k in range(1, 45):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(Data_train, Target_train)
    x_coords.append(k)
    y_coords.append(knn.score(Data_test, Target_test)*100)

plot.figure(1)
plot.plot(x_coords,y_coords)
plot.ylim(top = 100)
plot.xlabel("Value of k")
plot.ylabel("Accuracy")
plot.title("Accuracy for different values of k")

#calculating min and max lengths/widths of the features
length_min, length_max = min(sepal_length) - 0.1, max(sepal_length) + 0.1
width_min, width_max = min(sepal_width) - 0.1, max(sepal_width) + 0.1
#numpy.meshgrid() used to return coordinate matrices
xx, yy = numpy.meshgrid(numpy.linspace(length_min, length_max, 100), numpy.linspace(width_min, width_max, 100))
#training the dataset. change n_neighbours value to view the decision boundary change
knn_plotter = KNeighborsClassifier(n_neighbors=8)
knn_plotter.fit(Data_train, Target_train)
#predicting the decision boundaries relative to the dots
Z = knn_plotter.predict(numpy.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plot.figure(2)
plot.pcolormesh(xx, yy, Z, cmap = cmap_light)
plot.scatter(sepal_length, sepal_width, c=irisDataset.target, cmap=cmap_bold)
plot.xlabel("sepal length (cm)")
plot.ylabel("sepal width (cm)")
plot.colorbar(ticks=[0, 1, 2], format=formatterplot)
plot.show()
